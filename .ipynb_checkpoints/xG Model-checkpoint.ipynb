# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import rcParams
import matplotlib.pyplot as plt

from mplsoccer import Pitch, VerticalPitch, FontManager, Sbopen
from matplotlib.colors import LinearSegmentedColormap

import plotly.express as px

from sqlalchemy import create_engine
import pymysql
from pymysql.cursors import DictCursor
import pymysql.cursors

#import warnings
#warnings.filterwarnings('ignore')

# %%
username = 'root'          
password = ''               
host = 'localhost'         
port = '3306'              
database = 'top7_leagues' 

# Create the SQLAlchemy engine
engine = create_engine(f'mysql+pymysql://{username}:{password}@{host}:{port}/{database}')

# %%
query = "SELECT * FROM match_events_2023_24"
df_events = pd.read_sql(query, engine)

# %%
df_events.head()
# Out:
#            id  match_id  event_id  minute  second  team_id  player_id     x
# 0  2602361573   1734766         3       0     0.0       54     135366  50.1  \
# 1  2602361601   1734766         4       0     1.0       54      82989  46.1
# 2  2602361647   1734766         5       0     4.0       54     125211  31.8
# 3  2602361695   1734766         6       0     6.0       54     121456  20.8
# 4  2602361767   1734766         7       0     9.0       54     454342  19.4
#
#       y  end_x  ...  blocked_x blocked_y  goal_mouth_z  goal_mouth_y  is_shot
# 0  50.0   46.4  ...        NaN       NaN           NaN           NaN        0  \
# 1  49.7   31.9  ...        NaN       NaN           NaN           NaN        0
# 2  13.1   20.8  ...        NaN       NaN           NaN           NaN        0
# 3  30.8   20.1  ...        NaN       NaN           NaN           NaN        0
# 4  64.2   18.1  ...        NaN       NaN           NaN           NaN        0
#
#    card_type  is_goal  type_display_name  outcome_type_display_name
# 0          0        0               Pass                 Successful  \
# 1          0        0               Pass                 Successful
# 2          0        0               Pass                 Successful
# 3          0        0               Pass                 Successful
# 4          0        0               Pass                 Successful
#
#    period_display_name
# 0            FirstHalf
# 1            FirstHalf
# 2            FirstHalf
# 3            FirstHalf
# 4            FirstHalf
#
# [5 rows x 23 columns]

# %%
df_events['type_display_name'].unique()
# Out:
# array(['Pass', 'TakeOn', 'Foul', 'Aerial', 'BallRecovery', 'BlockedPass',
#        'Interception', 'Dispossessed', 'Tackle', 'BallTouch', 'Challenge',
#        'Clearance', 'CornerAwarded', 'Punch', 'MissedShots',
#        'KeeperPickup', 'OffsidePass', 'OffsideProvoked', 'SavedShot',
#        'Save', 'ShotOnPost', 'Goal', 'Card', 'SubstitutionOff',
#        'SubstitutionOn', 'ShieldBallOpp', 'PenaltyFaced', 'Smother',
#        'GoodSkill', 'Claim', 'CrossNotClaimed', 'KeeperSweeper', 'Error',
#        'ChanceMissed', 'FormationChange'], dtype=object)

# %%
# Add the is_penalty column with default value 0
df_events['PenaltyFaced'] = np.where(df_events['type_display_name']=='PenaltyFaced',1,0)

# %%
df_events['event_after_pen'] = np.where(df_events['PenaltyFaced']==1, df_events['type_display_name'].shift(-1), 0)
df_events['event_before_pen'] = np.where(df_events['PenaltyFaced']==1, df_events['type_display_name'].shift(1), 0)

# %%
df_penalties = df_events[df_events['PenaltyFaced']==1]
df_penalties.head()
# Out:
#                id  match_id  event_id  minute  second  team_id  player_id
# 1561   2664554577   1729318        34       5    22.0       29      92516  \
# 2702   2664647995   1729318       603      76    44.0       29      20973
# 4026   2650604675   1741125       553      59     9.0      148     430870
# 6109   2629578175   1729498      1119      94    28.0      167     121774
# 22837  2633026079   1748477       598      74     5.0    28635     463346
#
#          x    y  end_x  ...  goal_mouth_y is_shot  card_type  is_goal
# 1561   0.0  0.0    NaN  ...           NaN       0          0        0  \
# 2702   0.0  0.0    NaN  ...           NaN       0          0        0
# 4026   0.0  0.0    NaN  ...           NaN       0          0        0
# 6109   0.0  0.0    NaN  ...           NaN       0          0        0
# 22837  0.0  0.0    NaN  ...           NaN       0          0        0
#
#        type_display_name  outcome_type_display_name  period_display_name
# 1561        PenaltyFaced               Unsuccessful            FirstHalf  \
# 2702        PenaltyFaced               Unsuccessful           SecondHalf
# 4026        PenaltyFaced               Unsuccessful           SecondHalf
# 6109        PenaltyFaced               Unsuccessful           SecondHalf
# 22837       PenaltyFaced               Unsuccessful           SecondHalf
#
#        PenaltyFaced  event_after_pen  event_before_pen
# 1561              1             Pass              Goal
# 2702              1             Goal              Foul
# 4026              1             Goal              Foul
# 6109              1  SubstitutionOff              Goal
# 22837             1        SavedShot    SubstitutionOn
#
# [5 rows x 26 columns]

# %%
relevant_events = ['Goal', 'SavedShot', 'MissedShots', 'ShotOnPost']
# Create the shift_1 DataFrame where 'event_after_pen' matches the relevant events
shift_1_after = df_penalties[df_penalties['event_after_pen'].isin(relevant_events)]
shift_1_before = df_penalties[df_penalties['event_before_pen'].isin(relevant_events)]

# %%
# Perform an outer merge on 'id' column, keeping all rows from df_events and merging the corresponding rows from shift_1_after
df_events = pd.merge(df_events, shift_1_after[['id', 'event_after_pen']], on='id', how='outer')
df_events = pd.merge(df_events, shift_1_before[['id', 'event_before_pen']], on='id', how='outer')

# %%
df_events.head()
# Out:
#            id  match_id  event_id  minute  second  team_id  player_id     x
# 0  2602361573   1734766         3       0     0.0       54     135366  50.1  \
# 1  2602361601   1734766         4       0     1.0       54      82989  46.1
# 2  2602361647   1734766         5       0     4.0       54     125211  31.8
# 3  2602361695   1734766         6       0     6.0       54     121456  20.8
# 4  2602361767   1734766         7       0     9.0       54     454342  19.4
#
#       y  end_x  ...  card_type is_goal  type_display_name
# 0  50.0   46.4  ...          0       0               Pass  \
# 1  49.7   31.9  ...          0       0               Pass
# 2  13.1   20.8  ...          0       0               Pass
# 3  30.8   20.1  ...          0       0               Pass
# 4  64.2   18.1  ...          0       0               Pass
#
#    outcome_type_display_name  period_display_name  PenaltyFaced
# 0                 Successful            FirstHalf             0  \
# 1                 Successful            FirstHalf             0
# 2                 Successful            FirstHalf             0
# 3                 Successful            FirstHalf             0
# 4                 Successful            FirstHalf             0
#
#    event_after_pen_x  event_before_pen_x  event_after_pen_y
# 0                  0                   0                NaN  \
# 1                  0                   0                NaN
# 2                  0                   0                NaN
# 3                  0                   0                NaN
# 4                  0                   0                NaN
#
#    event_before_pen_y
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
#
# [5 rows x 28 columns]

# %%
# First, initialize the is_penalty column to NaN (or 0, if you prefer)
df_events['is_penalty'] = 0

# Step 1: Mark the row *after* event_after_pen_y is not NaN
df_events['is_penalty'] = np.where(df_events['event_after_pen_y'].notna().shift(1), 1, df_events['is_penalty'])

# Step 2: Mark the row *before* event_before_pen_y is not NaN
df_events['is_penalty'] = np.where(df_events['event_before_pen_y'].notna().shift(-1), 1, df_events['is_penalty'])

# %%
# Correct list of columns to drop
col_to_drop = ['PenaltyFaced', 'event_after_pen_x', 'event_before_pen_x', 'event_after_pen_y', 'event_before_pen_y']
# Drop the columns from df_events
df_events = df_events.drop(columns=col_to_drop)

# %%
df_events.head()
# Out:
#            id  match_id  event_id  minute  second  team_id  player_id     x
# 0  2602361573   1734766         3       0     0.0       54     135366  50.1  \
# 1  2602361601   1734766         4       0     1.0       54      82989  46.1
# 2  2602361647   1734766         5       0     4.0       54     125211  31.8
# 3  2602361695   1734766         6       0     6.0       54     121456  20.8
# 4  2602361767   1734766         7       0     9.0       54     454342  19.4
#
#       y  end_x  ...  blocked_y goal_mouth_z  goal_mouth_y  is_shot  card_type
# 0  50.0   46.4  ...        NaN          NaN           NaN        0          0  \
# 1  49.7   31.9  ...        NaN          NaN           NaN        0          0
# 2  13.1   20.8  ...        NaN          NaN           NaN        0          0
# 3  30.8   20.1  ...        NaN          NaN           NaN        0          0
# 4  64.2   18.1  ...        NaN          NaN           NaN        0          0
#
#    is_goal  type_display_name  outcome_type_display_name  period_display_name
# 0        0               Pass                 Successful            FirstHalf  \
# 1        0               Pass                 Successful            FirstHalf
# 2        0               Pass                 Successful            FirstHalf
# 3        0               Pass                 Successful            FirstHalf
# 4        0               Pass                 Successful            FirstHalf
#
#    is_penalty
# 0           1
# 1           0
# 2           0
# 3           0
# 4           0
#
# [5 rows x 24 columns]

# %%
# Apply transformations to x and y coordinates
for col in ['x', 'end_x','blocked_x']:
    df_events.loc[:, col] *= 1.2
for col in ['y', 'end_y', 'blocked_y', 'goal_mouth_y']:
    df_events.loc[:, col] = 80 - (df_events[col] * 0.8)

# %%
df_shots = df_events[df_events['is_shot']==1]

# %%
df_shots.columns
# Out:
# Index(['id', 'match_id', 'event_id', 'minute', 'second', 'team_id',
#        'player_id', 'x', 'y', 'end_x', 'end_y', 'qualifiers', 'is_touch',
#        'blocked_x', 'blocked_y', 'goal_mouth_z', 'goal_mouth_y', 'is_shot',
#        'card_type', 'is_goal', 'type_display_name',
#        'outcome_type_display_name', 'period_display_name', 'is_penalty'],
#       dtype='object')

# %%
columns_to_drop = ['id', 'match_id', 'event_id', 'second','team_id', 'player_id', 
                   'qualifiers', 'card_type', 'outcome_type_display_name','is_touch',
                   'period_display_name','end_x','end_y']
df_shots = df_shots.drop(columns=columns_to_drop)

# %%
df_shots['type_display_name'].unique()
# Out:
# array(['MissedShots', 'SavedShot', 'ShotOnPost', 'Goal'], dtype=object)

# %%
# Mapping logic: 1 = on target, 0 = off target
df_shots['is_on_target'] = df_shots['type_display_name'].map({
    'MissedShots': 0,
    'SavedShot': 1,
    'ShotOnPost': 0,
    'Goal': 1
})

# %%
df_shots['was_blocked'] = df_shots['blocked_x'].notna().astype(int)

# %%
df_shots['distance_blocker_goal'] = np.sqrt((df_shots['blocked_x'] - 120)**2 + (df_shots['blocked_y'] - 40)**2)
df_shots['distance_shooter_blocker'] = np.sqrt((df_shots['blocked_x'] - df_shots['x'])**2 + (df_shots['blocked_y'] - df_shots['y'])**2)

# %%
columns_to_drop = ['type_display_name','is_shot']
df_shots = df_shots.drop(columns=columns_to_drop)

# %%
df_shots.head()
# Out:
#      minute       x      y  blocked_x  blocked_y  goal_mouth_z  goal_mouth_y
# 75        4  117.48  47.68        NaN        NaN          72.2         46.64  \
# 217      12   97.32  41.92     117.72      40.16           5.1         41.84
# 296      17  110.04  35.60        NaN        NaN           6.9         33.60
# 305      17  107.40  35.60        NaN        NaN          80.6         37.12
# 395      23  108.12  22.88        NaN        NaN           5.7         44.48
#
#      is_goal  is_penalty  is_on_target  was_blocked  distance_blocker_goal
# 75         0           0             0            0                    NaN  \
# 217        0           0             1            1               2.285607
# 296        0           0             0            0                    NaN
# 305        0           0             0            0                    NaN
# 395        0           0             0            0                    NaN
#
#      distance_shooter_blocker
# 75                        NaN
# 217                 20.475781
# 296                       NaN
# 305                       NaN
# 395                       NaN

# %%
# Goal center coordinates
goal_x = 120
goal_y = 40

# Calculate shot distance
df_shots['shot_distance'] = np.sqrt((df_shots['x'] - goal_x)**2 + (df_shots['y'] - goal_y)**2)

# Calculate shot angle in radians
df_shots['shot_angle'] = np.arctan2(np.abs(df_shots['y'] - goal_y), np.abs(goal_x - df_shots['x']))

# Convert angle to degrees (optional)
df_shots['shot_angle_deg'] = np.degrees(df_shots['shot_angle'])

# %%
# Drop the 'shot_angle' column
df_shots = df_shots.drop(columns=['shot_angle'])

# %%
df_shots.head()
# Out:
#      minute       x      y  blocked_x  blocked_y  goal_mouth_z  goal_mouth_y
# 75        4  117.48  47.68        NaN        NaN          72.2         46.64  \
# 217      12   97.32  41.92     117.72      40.16           5.1         41.84
# 296      17  110.04  35.60        NaN        NaN           6.9         33.60
# 305      17  107.40  35.60        NaN        NaN          80.6         37.12
# 395      23  108.12  22.88        NaN        NaN           5.7         44.48
#
#      is_goal  is_penalty  is_on_target  was_blocked  distance_blocker_goal
# 75         0           0             0            0                    NaN  \
# 217        0           0             1            1               2.285607
# 296        0           0             0            0                    NaN
# 305        0           0             0            0                    NaN
# 395        0           0             0            0                    NaN
#
#      distance_shooter_blocker  shot_distance  shot_angle_deg
# 75                        NaN       8.082871       71.834043
# 217                 20.475781      22.761125        4.838899
# 296                       NaN      10.888600       23.834263
# 305                       NaN      13.346160       19.249526
# 395                       NaN      20.838157       55.242243

# %% [raw]
# # Plot distributions of blocked_x and blocked_y
# plt.figure(figsize=(12, 6))
#
# # Distribution of blocked_x
# plt.subplot(1, 2, 1)
# sns.histplot(df_shots['x'].dropna(), bins=30, kde=True)
# plt.title('Distribution of X Positions')
#
# # Distribution of blocked_y
# plt.subplot(1, 2, 2)
# sns.histplot(df_shots['y'].dropna(), bins=30, kde=True)
# plt.title('Distribution of Y Positions')
#
# plt.tight_layout()
# plt.show()

# %% [raw]
# plt.figure(figsize=(14, 6))
#
# # Box plot for blocked_x
# plt.subplot(1, 2, 1)
# sns.boxplot(data=df_shots, x='blocked_x')
# plt.title('Box Plot of Blocked X Positions')
#
# # Box plot for blocked_y
# plt.subplot(1, 2, 2)
# sns.boxplot(data=df_shots, x='blocked_y')
# plt.title('Box Plot of Blocked Y Positions')
#
# plt.tight_layout()
# plt.show()

# %% [raw]
# plt.figure(figsize=(14, 6))
#
# # Box plot for blocked_x
# plt.subplot(1, 2, 1)
# sns.boxplot(data=df_shots, x='distance_blocker_goal')
# plt.title('Box Plot of distance_blocker_goal')
#
# # Box plot for blocked_y
# plt.subplot(1, 2, 2)
# sns.boxplot(data=df_shots, x='distance_shooter_blocker')
# plt.title('Box Plot of distance_shooter_blocker')
#
# plt.tight_layout()
# plt.show()
